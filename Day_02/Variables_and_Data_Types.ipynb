# %%
name  = "Rovin Chauhan"
age = 28
experince = "1.2 years"

print("Name:", name)
print("Age:", age)
print("Experince:", experince)

print(type(name))
print(type(age))
print(type(experince))
# Out:
# Name: Rovin Chauhan
# Age: 28
# Experince: 1.2 years
# <class 'str'>
# <class 'int'>
# <class 'str'>
