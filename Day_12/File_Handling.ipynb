# %% [markdown]
# 1. Read a Text File

# %%
with open("sample.txt", "r") as file:
    content = file.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1206/3277406587.py in <cell line: 0>()
# ----> 1 with open("sample.txt", "r") as file:
#       2     content = file.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample.txt'

# %% [markdown]
# 2. Read Line by Line

# %%
with open("sample.txt", "r") as file:
    for line in file:
        print(line.strip())
# Out:
# True
# True

# %% [markdown]
# 3. Write to a File

# %%
with open("notes.txt", "w") as file:
    file.write("Learning Python for Data Analytics")

# %% [markdown]
# 4. Append to a File

# %%
with open("notes.txt", "a") as file:
    file.write("\nDay 13 completed")
